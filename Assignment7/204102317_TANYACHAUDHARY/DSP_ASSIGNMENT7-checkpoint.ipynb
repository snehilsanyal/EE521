# %% [markdown]
# # ANALOG FILTERS

# %% [markdown]
# ### PARTS OF ANALOG FILTER QUESTION

# %%
from IPython.display import Image
Image(r"C:\Users\tanya\Downloads\as1.jpeg")

# %%
from IPython.display import Image
Image(r"C:\Users\tanya\Downloads\as2.jpeg")

# %%
from IPython.display import Image
Image(r"C:\Users\tanya\Downloads\as3.jpeg")

# %%
from IPython.display import Image
Image(r"C:\Users\tanya\Downloads\as4.jpeg")

# %% [markdown]
# ### MAGNITUDE AND PHASE SPECTRUM

# %%
import numpy as np
import matplotlib.pyplot as plt

r=47*1000
c=(47)*10**(-9)
f=np.arange(1,100,1)
w=2*np.pi*f;
h=np.abs(1/(((1j*r*w*c))+1))
plt.subplot (2,1,1)
plt.plot(f,h)
plt.title('Magnitude plot')
plt.xlabel ('w')
plt.ylabel ('|H(j\omega)')
theta=np.angle(1/(((1j*r*w*c))+1))
plt.subplot (2,1,2)
degree=theta*180/np.pi;
plt.plot(f, degree)
plt.title('Phase plot')
plt.xlabel('w')
plt.ylabel('\theta(j\omega)')
plt.tight_layout()
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import matplotlib.pyplot as plt

r=47*1000
c=47*(10**(-9))
f=np.arange(1,200,1)
w=2*np.pi*f;
h=np.abs(r*1j*w*c/(((1j*r*w*c))+1))
plt.subplot (2,1,1)
plt.plot(h)
plt.title('Magnitude Plot')
plt.xlabel ('w')
plt.ylabel ('|H(j\omega)')
theta=np.angle(r*1j*w*c/(((1j*r*w*c))+1))
plt.subplot (2,1,2)
degree=theta*180/np.pi;
plt.plot( degree)
plt.title('Phase Plot')
plt.xlabel('w')
plt.ylabel('\theta(j\omega)')
# Out:
# Text(0, 0.5, '\theta(j\\omega)')
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## DESIGN A SECOND ORDER LOW PASS FILTER USING RC CIRCUIT

# %%
import numpy as np
import matplotlib.pyplot as plt


R2 = 50000 # ohm
C2 = 50*10**(-9) # farad
freq = np.arange(1,100,1)
w = 2*np.pi*freq

H = 1/(1+3j*w2*C2*R2+((1j*w2)**2)*(C2**2)*(R2**2))

plot = [np.abs(H),np.angle(H)]
name = ['magnitude','phase']    
c =1
for k in range(len(plot)):
    
    plt.subplot(2,1,c)
    plt.plot(plot[k])
    plt.title(str(name[k])+" plot")
    plt.xlabel("Time")
    plt.ylabel(str(name[k]),fontsize=20)
    plt.axvline(x=0,color='k')
    c =c+1 
    plt.tight_layout()

# %% [markdown]
# ## DESIGN A BANDPASS CIRCUIT USING CASCADED RC CIRCUITS

# %%
r = 20000  
f_1 = 1000  
f_2 = 30000 
c1 = 1/(2*np.pi*r*f_1)
c2 = 1/(2*np.pi*r*f_2)
freq = np.arange(500,40000,500)
w = 2*np.pi*freq

H = ((1j*w*r*c1))/((1+1j*w*r*c1)*(1+1j*w*r*c2))

plot = [np.abs(H),np.angle(H)]
name = ['magnitude','phase']    
c =1
for k in range(len(plot)):
    plt.subplot(2,1,c)
    plt.plot(plot[k])
    plt.title(str(name[k])+" plot")
    plt.xlabel("Time")
    plt.ylabel(str(name[k]),fontsize=20)
    plt.axvline(x=0,color='k')
    c =c+1

# %% [markdown]
# # DIGITAL FILTERS

# %%
import numpy as np
import matplotlib.pyplot as plt


w=np.linspace(0,20,1000)
h=np.abs(1+np.exp(-1*1j*w))
plt.subplot (2,1,1)
plt.plot(w,h)
plt.title('Magnitude plot')
plt.xlabel ('\omega')
plt.ylabel ('|H(j\omega)')
theta=np.angle(1+np.exp(-1*1j*w))
plt.subplot (2,1,2)
degree=theta*180/np.pi;
plt.plot(w, degree)
plt.title('Phase plot')
plt.xlabel('\omega')
plt.ylabel('\theta(j\omega)')
plt.tight_layout()
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import matplotlib.pyplot as plt


f = np.arange(0,20,1)
sin_inp = np.sin(f)
h_1 = 2*abs(np.cos(1/2))
phase = np.arctan(np.sin(1)/(1+np.cos(1))) - 1
out = h_1*np.sin(f+phase)
plt.subplot(1, 2, 1)
plt.title("Input signal")
plt.stem(f,inp)
plt.subplot(1, 2, 2)
plt.title("Output signal")
plt.stem(f,out)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt


w=np.linspace(0,20,1000)
h=np.abs((np.exp(-2*1j*w)+np.exp(-1*1j*w)+1)/3)
plt.subplot (2,1,1)
plt.plot(w,h)
plt.title('Magnitude plot')
plt.xlabel ('\omega')
plt.ylabel ('|H(j\omega)')
theta=np.angle((np.exp(-2*1j*w)+np.exp(-1*1j*w)+1)/3)
plt.subplot (2,1,2)
degree=theta*180/np.pi;
plt.plot(w, degree)
plt.title('phase plot')
plt.xlabel('\omega')
plt.ylabel('\theta(j\omega)')
plt.tight_layout()
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import matplotlib.pyplot as plt


w=np.linspace(0,20,1000)
h=np.abs(np.exp(-2*1j*w)/4+np.exp(-1*1j*w)/2+1/4)
plt.subplot (2,1,1)
plt.plot(w,h)
plt.title('Magnitude plot')
plt.xlabel ('\omega')
plt.ylabel ('|H(j\omega)')
theta=np.angle(np.exp(-2*1j*w)/4+np.exp(-1*1j*w)/2+1/4)
plt.subplot (2,1,2)
degree=theta*180/np.pi;
plt.plot(w, degree)
plt.title('Phase plot')
plt.xlabel('\omega')
plt.ylabel('\theta(j\omega)')
plt.tight_layout()
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tanya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # MEAN AND MEDIAN FILTER

# %% [markdown]
# ### Mean filtering

# %%
import cv2
import numpy as np
   
      
# Read the image
img = cv2.imread(r'C:\Users\tanya\Downloads\dsp.jpeg',0)
  
# Obtain number of rows and columns 
# of the image
m, n = img.shape
   
# Develop Averaging filter(3, 3) mask
mask = np.ones([3, 3], dtype = int)
mask = mask / 9
   
# Convolve the 3X3 mask over the image 
img_new = np.zeros([m, n])
  
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
         
        img_new[i, j]= temp
          
img_new = img_new.astype(np.uint8)
compare = np.concatenate((img, img_new), axis=1) #side by side comparison

cv2.imshow('img', compare)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %% [markdown]
# ### Median filtering

# %%
# Median Spatial Domain Filtering
  
  
import cv2
import numpy as np
  
  
# Read the image
img_noisy1 = cv2.imread(r'C:\Users\tanya\Downloads\dsp.jpeg', 0)
  
# Obtain the number of rows and columns 
# of the image
m, n = img_noisy1.shape
   
# Traverse the image. For every 3X3 area, 
# find the median of the pixels and
# replace the ceter pixel by the median
img_new1 = np.zeros([m, n])
  
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = [img_noisy1[i-1, j-1],
               img_noisy1[i-1, j],
               img_noisy1[i-1, j + 1],
               img_noisy1[i, j-1],
               img_noisy1[i, j],
               img_noisy1[i, j + 1],
               img_noisy1[i + 1, j-1],
               img_noisy1[i + 1, j],
               img_noisy1[i + 1, j + 1]]
          
        temp = sorted(temp)
        img_new1[i, j]= temp[4]
  
img_new1 = img_new1.astype(np.uint8)
compare = np.concatenate((img, img_new1), axis=1) #side by side comparison

cv2.imshow('img', compare)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %% [markdown]
# The mean filter is a simple sliding-window spatial filter that replaces the center value in the window with the average (mean) of all the pixel values in the window. The window, or kernel, is usually square but can be any shape.
#
# The median filter is also a sliding-window spatial filter, but it replaces the center value in the window with the median of all the pixel values in the window.
#
# By calculating the median value of a neighborhood rather than the mean filter, the median filter has two main advantages over the mean filter:
# The median is a more robust average than the mean and so a single very unrepresentative pixel in a neighborhood will not affect the median value significantly.
# Since the median value must actually be the value of one of the pixels in the neighborhood, the median filter does not create new unrealistic pixel values when the filter straddles an edge. For this reason the median filter is much better at preserving sharp edges than the mean filter.

# %% [markdown]
# ### Original image

# %%
import cv2
import numpy as np
from skimage.util import random_noise
 
# Load the image
img = cv2.imread(r'C:\Users\tanya\Downloads\lenna.jpg')
cv2.imshow('Original image',img)

# %% [markdown]
# ### Image after adding salt and pepper noise

# %%
# Add salt-and-pepper noise to the image.
noise_img = random_noise(img, mode='s&p',amount=0.3)
 
# The above function returns a floating-point image
# on the range [0, 1], thus we changed it to 'uint8'
# and from [0,255]
noise_img = np.array(255*noise_img, dtype = 'uint8')
 
# Display the noise image
cv2.imshow('salt and pepper noise',noise_img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### To remove salt and pepper noise we use median filter

# %%
import cv2
import numpy as np
  
  
# Read the image
img_noisy1 = np.copy(noise_img[:,:,0])

  
# Obtain the number of rows and columns 
# of the image
m, n = img_noisy1.shape
   
# Traverse the image. For every 3X3 area, 
# find the median of the pixels and
# replace the ceter pixel by the median
img_new1 = np.zeros([m, n])
  
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = [img_noisy1[i-1, j-1],
               img_noisy1[i-1, j],
               img_noisy1[i-1, j + 1],
               img_noisy1[i, j-1],
               img_noisy1[i, j],
               img_noisy1[i, j + 1],
               img_noisy1[i + 1, j-1],
               img_noisy1[i + 1, j],
               img_noisy1[i + 1, j + 1]]
          
        temp = sorted(temp)
        img_new1[i, j]= temp[4]
  
img_new1 = img_new1.astype(np.uint8)


cv2.imshow('filtered image',img_new1)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %% [markdown]
# ### Image after adding speckle noise

# %%
import cv2
import numpy as np
 
img = cv2.imread(r'C:\Users\tanya\Downloads\lenna.jpg')
 
gauss = np.random.normal(0,1,img.size)
gauss = gauss.reshape(img.shape[0],img.shape[1],img.shape[2]).astype('uint8')
noise = img + img * gauss
 
cv2.imshow('speckle noise',noise)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### We use mean , average filtering for speckle noise removal

# %%
import cv2
import numpy as np
   
      
# Read the image
img = np.copy(noise[:,:,0])
  
# Obtain number of rows and columns 
# of the image
m, n = img.shape
   
# Develop Averaging filter(3, 3) mask
mask = np.ones([3, 3], dtype = int)
mask = mask / 9
   
# Convolve the 3X3 mask over the image 
img_new = np.zeros([m, n])
  
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
         
        img_new[i, j]= temp
          
img_new = img_new.astype(np.uint8)
compare = np.concatenate((img, img_new), axis=1) #side by side comparison

cv2.imshow('img', compare)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %% [markdown]
# Ways to convert an analog filter into a digital filter altogether and using these technique to convert all the analog filters
# into digital filters and plot the amplitude and frequency plots.

# %% [markdown]
# There are many techniques which are used to convert analog filter into digital filter of which the most used ones are  bilinear transformation, impulse invariance and there are many other methods also. Here we have used bilinear transformation

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

fs = 100
bf = 2 * np.pi * np.array([7, 13])
filts = signal.lti(*signal.butter(4, bf, btype='bandpass', analog=True,
                                  output='zpk'))
filtz = signal.lti(*signal.bilinear_zpk(filts.zeros, filts.poles,
                                        filts.gain, fs))
wz, hz = signal.freqz_zpk(filtz.zeros, filtz.poles, filtz.gain)
ws, hs = signal.freqs_zpk(filts.zeros, filts.poles, filts.gain,
                          worN=fs*wz)
plt.semilogx(wz*fs/(2*np.pi), 20*np.log10(np.abs(hz).clip(1e-15)),
             label=r'$|H_z(e^{j \omega})|$')
plt.semilogx(wz*fs/(2*np.pi), 20*np.log10(np.abs(hs).clip(1e-15)),
             label=r'$|H(j \omega)|$')
plt.legend()
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

fs = 100
bf = 2 * np.pi * np.array([7, 13])
filts = signal.lti(*signal.butter(4,10, btype='low', analog=True,
                                  output='zpk'))
filtz = signal.lti(*signal.bilinear_zpk(filts.zeros, filts.poles,
                                        filts.gain, fs))
wz, hz = signal.freqz_zpk(filtz.zeros, filtz.poles, filtz.gain)
ws, hs = signal.freqs_zpk(filts.zeros, filts.poles, filts.gain,
                          worN=fs*wz)
plt.semilogx(wz*fs/(2*np.pi), 20*np.log10(np.abs(hz).clip(1e-15)),
             label=r'$|H_z(e^{j \omega})|$')
plt.semilogx(wz*fs/(2*np.pi), 20*np.log10(np.abs(hs).clip(1e-15)),
             label=r'$|H(j \omega)|$')
plt.legend()
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

fs = 100
bf = 2 * np.pi * np.array([7, 13])
filts = signal.lti(*signal.butter(4,100, btype='high', analog=True,
                                  output='zpk'))
filtz = signal.lti(*signal.bilinear_zpk(filts.zeros, filts.poles,
                                        filts.gain, fs))
wz, hz = signal.freqz_zpk(filtz.zeros, filtz.poles, filtz.gain)
ws, hs = signal.freqs_zpk(filts.zeros, filts.poles, filts.gain,
                          worN=fs*wz)
plt.semilogx(wz*fs/(2*np.pi), 20*np.log10(np.abs(hz).clip(1e-15)),
             label=r'$|H_z(e^{j \omega})|$')
plt.semilogx(wz*fs/(2*np.pi), 20*np.log10(np.abs(hs).clip(1e-15)),
             label=r'$|H(j \omega)|$')
plt.legend()
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
