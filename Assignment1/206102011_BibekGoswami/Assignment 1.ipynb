# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import signal

# %% [markdown]
# 1. Continuous Signal
#
# Basic Signal

# %%
def u(t):
    x = []
    for i in range(len(t)):
        if t[i] < 0:
            x.append(0)
        else:
            x.append(1)
    return x

def r(t):
    x = []
    for i in range(len(t)):
        if t[i] < 0:
            x.append(0)
        else:
            x.append(t[i])
    return x

def p(t):
    x = []
    for i in range(len(t)):
        if t[i] < 0:
            x.append(0)
        else:
            x.append((t[i]**2)/2)
    return x

def p(t):
    x = []
    for i in range(len(t)):
        if t[i] < 0:
            x.append(0)
        else:
            x.append((t[i]**2)/2)
    return x

def rect(t,tou):
    x = []
    for i in range(len(t)):
        if t[i] < (-tou/2) or t[i] > (tou/2):
            x.append(0)
        else:
            x.append(1)
    return x

def tri(t,tou):
    x = []
    for i in range(len(t)):
        if t[i] < (-tou/2) or t[i] > (tou/2):
            x.append(0)
        elif t[i] > (-tou/2) and t[i] < 0:
            x.append(1+((2/tou)*t[i]))
        elif t[i] > 0 and t[i] < (tou/2):
            x.append(1-(2*t[i]/tou))
    return x

def sinc(t):
    x = []
    for i in range(len(t)):
        x.append((np.sin(np.pi * t[i]) / (np.pi * t[i])))
    return x

t = np.linspace(-10,10,100)

# %%
x1 = u(t)

plt.plot(t,x1)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Unit Step Function')
# Out:
# Text(0.5, 1.0, 'Unit Step Function')

# %%
x2 = r(t)

plt.plot(t,x2)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Ramp Function')
# Out:
# Text(0.5, 1.0, 'Ramp Function')

# %%
x3 = p(t)

plt.plot(t,x3)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Parabolic Function')
# Out:
# Text(0.5, 1.0, 'Parabolic Function')

# %%
x4 = rect(t,4)

plt.plot(t,x4)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Rectangular Function')
# Out:
# Text(0.5, 1.0, 'Rectangular Function')

# %%
x5 = tri(t,4)

plt.plot(t,x5)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Triangular Function')
# Out:
# Text(0.5, 1.0, 'Triangular Function')

# %%
x6 = sinc(t)

plt.plot(t,x6)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Sinc Function')
# Out:
# Text(0.5, 1.0, 'Sinc Function')

# %%
x1_s = 5*np.array(u(t+2))

plt.plot(t,x1_s)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Amplitude Scaled & Time Shifted Unit Step Function')
# Out:
# Text(0.5, 1.0, 'Amplitude Scaled & Time Shifted Unit Step Function')

# %%
x2_s = 5*np.array(r(t+2))

plt.plot(t,x2_s)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Amplitude Scaled & Time Shifted Ramp Function')
# Out:
# Text(0.5, 1.0, 'Amplitude Scaled & Time Shifted Ramp Function')

# %%
x3_s = 5*np.array(p(t+2))

plt.plot(t,x3_s)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Amplitude Scaled & Time Shifted Parapolic Function')
# Out:
# Text(0.5, 1.0, 'Amplitude Scaled & Time Shifted Parapolic Function')

# %%
B=2

# %%
x1_t = u(t*B)

plt.plot(t,x1_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Time Scaled Unit Step Function')
# Out:
# Text(0.5, 1.0, 'Time Scaled Unit Step Function')

# %%
x2_t = r(B*t)

plt.plot(t,x2_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Time Scaled Ramp Function')
# Out:
# Text(0.5, 1.0, 'Time Scaled Ramp Function')

# %%
x3_t = p(B*t)

plt.plot(t,x3_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Time Scaled Parabolic Function')
# Out:
# Text(0.5, 1.0, 'Time Scaled Parabolic Function')

# %%
B=0.5

# %%
x1_t = u(t*B)

plt.plot(t,x1_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Time Scaled Unit Step Function')
# Out:
# Text(0.5, 1.0, 'Time Scaled Unit Step Function')

# %%
x2_t = r(B*t)

plt.plot(t,x2_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Time Scaled Ramp Function')
# Out:
# Text(0.5, 1.0, 'Time Scaled Ramp Function')

# %%
x3_t = p(B*t)

plt.plot(t,x3_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Time Scaled Parabolic Function')
# Out:
# Text(0.5, 1.0, 'Time Scaled Parabolic Function')

# %% [markdown]
# Exponentials

# %%
B = np.array([-5,-2,-0.5,-0.25,0,1,2])

# %%
A = -5
x=[]
for i in range(len(B)):
    x.append(A * np.exp(B[i]*t))

x = np.array(x)

plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('A*exp(B*t) for A =-5')

plt.plot(t,x[0],'r')
plt.plot(t,x[1],'g')
plt.plot(t,x[2],'b')
plt.plot(t,x[3],'y')
plt.plot(t,x[4],'o')
plt.plot(t,x[5],'v')
plt.plot(t,x[6],'p')

plt.show()

# %%
A = 5
x=[]
for i in range(len(B)):
    x.append(A * np.exp(B[i]*t))

x = np.array(x)

plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('A*exp(B*t) for A =5')

plt.plot(t,x[0],'r')
plt.plot(t,x[1],'g')
plt.plot(t,x[2],'b')
plt.plot(t,x[3],'y')
plt.plot(t,x[4],'o')
plt.plot(t,x[5],'v')
plt.plot(t,x[6],'p')

plt.show()

# %% [markdown]
# Sinusoids

# %%
x1 = 5 * np.sin( (2) * np.pi * t)

plt.plot(t,x1)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('5*Sin(2*pi*t)')
# Out:
# Text(0.5, 1.0, '5*Sin(2*pi*t)')

# %%
x2 = 2 * np.sin((2/3) * np.pi * t)

plt.plot(t,x2)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('2*sin(2*pi*t/3)')
# Out:
# Text(0.5, 1.0, '2*sin(2*pi*t/3)')

# %%
x3 = 2 * np.sin((1/3) * np.pi * t)

plt.plot(t,x3)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('2*sin(pi*t/3)')
# Out:
# Text(0.5, 1.0, '2*sin(pi*t/3)')

# %%
x4 = 3 * np.sin((2 * np.pi * t) + (np.pi/3))

plt.plot(t,x4)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('3*sin(2*pi*t + pi/3)')
# Out:
# Text(0.5, 1.0, '3*sin(2*pi*t + pi/3)')

# %%
x5 = x1 + x2

plt.plot(t,x5)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('x1+x2')
# Out:
# Text(0.5, 1.0, 'x1+x2')

# %%
x6 = x3 + x4

plt.plot(t,x6)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('x3+x4')
# Out:
# Text(0.5, 1.0, 'x3+x4')

# %%
x7 = x1 + x3

plt.plot(t,x7)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('x1+x3')
# Out:
# Text(0.5, 1.0, 'x1+x3')

# %%
x8 = 5 * np.sin( (-2) * np.pi * t)

plt.plot(t,x8)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('5*sin(-2*pi*t)')
# Out:
# Text(0.5, 1.0, '5*sin(-2*pi*t)')

# %%
x9 = 2 * np.sin((-1/3) * np.pi * t)

plt.plot(t,x9)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('2*sin(-pi*t/3)')
# Out:
# Text(0.5, 1.0, '2*sin(-pi*t/3)')

# %% [markdown]
# Complex Exponentials

# %%
# Aexp(Bt)cos(wt)
A = np.array([0.1,0.5,1,2])
B = np.array([-0.25,-0.5,-1,0.5,1])
w = np.array([2 * np.pi, np.pi / 6, 5/3 * np.pi])

for i in range(A.shape[0]):
    for j in range(B.shape[0]):
        for k in range(w.shape[0]):
            y = A[i] * np.exp(B[j] * t) * np.cos(w[k] * t)
            plt.plot(t,y)
            
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('A*exp(Bt)cos(wt)')
plt.show()

# %%
#Aexp(j(w*t+theta))
def y(A,w,theta,t):
    im = A * np.cos((w*t)+theta)
    re = A * np.sin((w*t)+theta)
    
    return im,re

# %%
#(A,w,theta) = (1,0.14*pi,0)
y_im, y_re = y(1, 0.14*np.pi, 0,t)

fig = plt.figure()

plt.subplot(1,2,1)
plt.plot(t,y_re)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Re(y(t))')

plt.subplot(1,2,2)
plt.plot(t,y_im)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Im(y(t))')

plt.show()

# %%
#(A,w,theta) = (1,0.14*pi,pi)
y_im, y_re = y(1, 0.14*np.pi, np.pi,t)

fig = plt.figure()

plt.subplot(1,2,1)
plt.plot(t,y_re)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Re(y(t))')

plt.subplot(1,2,2)
plt.plot(t,y_im)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Im(y(t))')

plt.show()

# %%
#(A,w,theta) = (2,0.34*pi,0.5*pi)
y_im, y_re = y(2, 0.34*np.pi, 0.5*np.pi,t)

fig = plt.figure()

plt.subplot(1,2,1)
plt.plot(t,y_re)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Re(y(t))')

plt.subplot(1,2,2)
plt.plot(t,y_im)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Im(y(t))')

plt.show()

# %%
#(A,w,theta) = (2,0.75*pi,pi/3)
y_im, y_re = y(2, 0.75*np.pi, np.pi/3,t)

fig = plt.figure()

plt.subplot(1,2,1)
plt.plot(t,y_re)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Re(y(t))')

plt.subplot(1,2,2)
plt.plot(t,y_im)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Im(y(t))')

plt.show()

# %% [markdown]
# 2. Discrete Signal

# %%
def delta_fun(n):
    x=[]
    for i in range(len(n)):
        if(n[i]==0):
            x.append(1)
        else:
            x.append(0)
            
    return x
    
n = np.arange(-10,11)

# %%
x1_n = delta_fun(n)

plt.stem(n,x1_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Delta of n')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'Delta of n')

# %%
x2_n = 3 * np.array(delta_fun(n))

plt.stem(n,x2_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('3*del(n)')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, '3*del(n)')

# %%
x3_n = 3 * np.array(delta_fun(2*n))

plt.stem(n,x3_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('3*del(2n)')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, '3*del(2n)')

# %%
x4_n = 3 * np.array(delta_fun(2*n - 5))

plt.stem(n,x4_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('3*del(2n-5)')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, '3*del(2n-5)')

# %%
x5_n = 3 * np.array(delta_fun(n*n + 3*n + 2))

plt.stem(n,x5_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('3*del(n^2+3n+2)')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, '3*del(n^2+3n+2)')

# %%
x6_n = x1_n + x2_n + x3_n

plt.stem(n,x6_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('x1[n]+x2[n]+x3[t]')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'x1[n]+x2[n]+x3[t]')

# %%
x7_n = delta_fun(n)

plt.stem(n,x7_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Delta of n')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'Delta of n')

# %%
for k in range(-10,11):
    x8_n = delta_fun(n-k)
    plt.stem(n,x8_n)

plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Impulse Train')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
x9_n = delta_fun(n)

plt.stem(n,x9_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Delta of n')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'Delta of n')

# %%
x1_t = u(n)

plt.stem(n,x1_t)    
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Discrete counter part of unit step signal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'Discrete counter part of unit step signal')

# %%
x2_t = r(n)

plt.stem(n,x2_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Discrete counter part of ramp signal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'Discrete counter part of ramp signal')

# %%
x3_t = p(n)

plt.stem(n,x3_t)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Discrete counter part of parabolic signal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'Discrete counter part of parabolic signal')

# %%
x3_n1 = p(n)
x3_n2 = p(n-1)
x3_n = []

for i in range(len(x3_n1)):
    x3_n.append(x3_n1[i]-x3_n2[i])
    
x3_n = np.array(x3_n)

plt.stem(n,x3_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Ramp signal from parabolic signal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # Remove the CWD from sys.path while we load stuff.
# Text(0.5, 1.0, 'Ramp signal from parabolic signal')

# %%
x2_n1 = r(n)
x2_n2 = r(n-1)
x2_n = []

for i in range(len(x2_n1)):
    x2_n.append(x2_n1[i]-x2_n2[i])
    
x2_n = np.array(x2_n)

plt.stem(n,x2_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Unit step signal from ramp signal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # Remove the CWD from sys.path while we load stuff.
# Text(0.5, 1.0, 'Unit step signal from ramp signal')

# %%
x1_n1 = u(n)
x1_n2 = u(n-1)
x1_n = []

for i in range(len(x1_n1)):
    x1_n.append(x1_n1[i]-x1_n2[i])
    
x1_n = np.array(x1_n)

plt.stem(n,x1_n)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Impulse signal from unit step signal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # Remove the CWD from sys.path while we load stuff.
# Text(0.5, 1.0, 'Impulse signal from unit step signal')

# %% [markdown]
# 3. Systems (Time domain approach)

# %%
def convolution(inputSeq, impulseResponse):
    outputSeq = np.convolve(inputSeq,impulseResponse)
    
    return outputSeq

# %%
x_n = np.array([2,4,5,2,7])
h_n = np.array([8,-5,4])

y_n = convolution(x_n,h_n)
print(y_n)
# Out:
# [ 16  22  28   7  66 -27  28]

# %%
h_n = 2*np.array(delta_fun(n-3))
n1 = np.arange(-20,21)

# %%
u_n = u(n)
y_unit_step = convolution(u_n,h_n)

plt.stem(n1,y_unit_step)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Response of unit step function')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Response of unit step function')

# %%
r_n = r(n)
y_ramp = convolution(r_n,h_n)

plt.stem(n1,y_ramp)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Response of ramp function')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Response of ramp function')

# %%
p_n = p(n)
y_parabolic = convolution(p_n,h_n)

plt.stem(n1,y_parabolic)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Response of parabolic function')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Response of parabolic function')

# %%
re_complex_exp = np.exp(2*n) * np.cos(3*n)
im_complex_exp = np.exp(2*n) * np.cos(3*n)

y_re_complex_exp = convolution(re_complex_exp,h_n)
y_im_complex_exp = convolution(im_complex_exp,h_n)

fig = plt.figure(figsize=(8,10))

plt.subplot(2,1,1)
plt.stem(n1,y_re_complex_exp)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Response of real part complex exponential')

plt.subplot(2,1,2)
plt.stem(n1,y_im_complex_exp)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Response of imaginary part complex exponential')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # Remove the CWD from sys.path while we load stuff.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   app.launch_new_instance()
